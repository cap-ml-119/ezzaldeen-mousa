# %% [markdown]
# # Bike Sharing Exploratory Data Analysis
# ### Trying to understand the data to know the best way to process it
#
# #### Data Fields
# * datetime - hourly date + timestamp
# * season -
#     * 1 = spring,
#     * 2 = summer,
#     * 3 = fall,
#     * 4 = winter
# * holiday - whether the day is considered a holiday
# * workingday - whether the day is neither a weekend nor holiday
# * weather -
#     * 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#     * 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     * 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     * 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# * temp - temperature in Celsius
# * atemp - "feels like" temperature in Celsius
# * humidity - relative humidity
# * windspeed - wind speed
# * casual - number of non-registered user rentals initiated
# * registered - number of registered user rentals initiated
# * count - number of total rentals

# %%
# import the libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load the date which is the training data for the model
data = pd.read_csv('./data/train.csv', parse_dates=['datetime'])

# %% [markdown]
# ### An overview on the data

# %%
data.shape
# Out:
# (10886, 12)

# %%
# get the top five observations
data.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# get the last five observations
data.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
# description for the data
data.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %% [markdown]
# > * There is no missing values in the training data :)
# > * All data is numeric except the datetime ( we will parse the datetime to transform it into numeric features )

# %%
# add more feature ( split the datetime feature into meaningful features)
data['year'] = data['datetime'].dt.year
data['month'] = data['datetime'].dt.month
data['day'] = data['datetime'].dt.day
data['day of week'] = data['datetime'].dt.dayofweek
data['hour'] = data['datetime'].dt.hour

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     10886 non-null  datetime64[ns]
#  1   season       10886 non-null  int64
#  2   holiday      10886 non-null  int64
#  3   workingday   10886 non-null  int64
#  4   weather      10886 non-null  int64
#  5   temp         10886 non-null  float64
#  6   atemp        10886 non-null  float64
#  7   humidity     10886 non-null  int64
#  8   windspeed    10886 non-null  float64
#  9   casual       10886 non-null  int64
#  10  registered   10886 non-null  int64
#  11  count        10886 non-null  int64
#  12  year         10886 non-null  int64
#  13  month        10886 non-null  int64
#  14  day          10886 non-null  int64
#  15  day of week  10886 non-null  int64
#  16  hour         10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(13)
# ...

# %%
# take a look at the changes that we got
data.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  \
# 0        81        0.0       3          13     16  2011      1    1
# 1        80        0.0       8          32     40  2011      1    1
# 2        80        0.0       5          27     32  2011      1    1
# 3        75        0.0       3          10     13  2011      1    1
# 4        75        0.0       0           1      1  2011      1    1
#
#    day of week  hour
# 0            5     0
# 1            5     1
# 2            5     2
# ...

# %% [markdown]
# #### At which season do we get the highest demand?

# %%
sns.set_style('darkgrid')
sns.barplot(data=data, x='season', y='count')
plt.show()

# %% [markdown]
# > 3: Fall then, 2: Summer, 4: Winter, and 1: Sprint comes with lowest demand

# %%
sns.barplot(data=data, x='weather', y='count')
plt.show()

# %% [markdown]
# > Weather 3 ( Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds ), comes with the lowest demand

# %%
sns.barplot(data=data, x='workingday', y='count')
plt.show()

# %%
sns.barplot(data=data, x='holiday', y='count')
plt.show()

# %%
plt.figure(figsize = (19,7))
data_correlation = data.corr()
sns.heatmap(data_correlation, annot = True, linewidths=0.1)
plt.show()

# %% [markdown]
# > * We noticed that we have a high correlation between **atemp** and **temp**, since we got that we could take one of them either 'atemp' or 'temp'
# > * Casual and Regestired have high correlated with count that because casual and registered are derived from count, so we could ignore them

# %%
plt.figure(figsize=(18,6))
sns.pointplot(x='hour', y='count', data=data, hue='day of week')
plt.show()

# %%
# get the percent of the registered and casual users
(data[['registered', 'casual']].sum() / data['count'].sum()).plot.pie(legend=True, autopct='%.2f%%')
plt.show()

# %% [markdown]
# > * More than 80% of the stakeholder are registered users in our train data

# %%
sns.pairplot(data)

# %% [markdown]
# ## Outlier Removal

# %%
sns.set_style('darkgrid')
sns.boxplot(x='count', data=data)
plt.show()

# %%
sns.boxplot(x='windspeed', data=data)
plt.show()

# %%
sns.boxplot(x='humidity', data=data)
plt.show()

# %%
columns_with_outlier = ['count', 'windspeed', 'humidity']
for col in columns_with_outlier:
    Q1 = data['windspeed'].quantile(0.25)
    Q3 = data['windspeed'].quantile(0.75)
    IQR = Q3 - Q1
    outliers = data[(data['windspeed'] < (Q1 - 1.5 * IQR)) | (data['windspeed'] > (Q3 + 1.5 * IQR))]
    # percentage of the outlires
    print(f'{col} with %', (len(outliers) / len(data))*100)
    
    # remove the outlires from the data
    indices_to_remove = outliers.index
    data.drop(index=indices_to_remove, axis='rows', inplace=True)
# Out:
# count with % 2.049877196296996
# windspeed with % 0.0
# humidity with % 0.0

# %% [markdown]
# ## Drop useless features
#
# * Registered, Casul: I don't need this feature because it derived from the count variable

# %%
useless_features = ['registered', 'casual']
data.drop(columns=useless_features, axis='columns', inplace=True)

# %% [markdown]
# ## Save the edited data

# %%
data.to_csv('./data/edited.csv', index=False)
